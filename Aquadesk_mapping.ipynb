# %%
from beacon_api import *
import pandas as pd
import csv
pd.set_option('display.max_columns', None)

# %%
client = Client("https://beacon-ihm.maris.nl")
# Out:
# Connected to: https://beacon-ihm.maris.nl/ server successfully

# %%
tables = client.list_tables()
tables['ihm_aquadesk_api'].get_table_schema()
# Out:
# Organisation: string
# Supplier: string
# Projects: string
# Code: string
# Description: string
# Parameter: string
# LifeForm: string
# Value: double
# Uom: string
# Count: double
# Type: string
# ResultOf: string
# SamplingMethod: string
# AnalysisMethod: string
# Compartment: string
# Geography: string
# ResultTime: string
# Quantity: string
# TaxonType: string
# TaxonRank: string
# TaxonGroup: string
# TaxonNameNl: string
# ParameterType: string
# Behaviour: string
# Sampler: string
# Completeness: string
# Statistic: string
# RecordingMethod: string
# KrwCode: string
# Purpose: string
# Source: string
# MeasurementPackage: string
# MonitoringNetworks: string
# longitude: double
# latitude: double

# %%
df_aquadesk= (
    tables["ihm_aquadesk_api"]
    .query()
    .add_select_column("Organisation")
    .add_select_column("Supplier")
    .add_select_column("Projects")
    .add_select_column("Code")
    .add_select_column("Description")
    .add_select_column("Parameter")
    .add_select_column("LifeForm")
    .add_select_column("Value")
    .add_select_column("Uom")
    .add_select_column("Count")
    .add_select_column("Type")
    .add_select_column("ResultOf")
    .add_select_column("SamplingMethod")
    .add_select_column("AnalysisMethod")
    .add_select_column("Compartment")
    .add_select_column("ResultTime")
    .add_select_column("Quantity")
    .add_select_column("TaxonType")
    .add_select_column("TaxonRank")
    .add_select_column("TaxonGroup")
    .add_select_column("TaxonNameNl")
    .add_select_column("ParameterType")
    .add_select_column("Behaviour")
    .add_select_column("Sampler")
    .add_select_column("Completeness")
    .add_select_column("Statistic")
    .add_select_column("RecordingMethod")
    .add_select_column("KrwCode")
    .add_select_column("Purpose")
    .add_select_column("Source")
    .add_select_column("MeasurementPackage")
    .add_select_column("MonitoringNetworks")
    .add_select_column("longitude")
    .add_select_column("latitude")
    .to_pandas_dataframe()
)
# Out:
# Running query: {"from": "ihm_aquadesk_api", "select": [{"column": "Organisation", "alias": null}, {"column": "Supplier", "alias": null}, {"column": "Projects", "alias": null}, {"column": "Code", "alias": null}, {"column": "Description", "alias": null}, {"column": "Parameter", "alias": null}, {"column": "LifeForm", "alias": null}, {"column": "Value", "alias": null}, {"column": "Uom", "alias": null}, {"column": "Count", "alias": null}, {"column": "Type", "alias": null}, {"column": "ResultOf", "alias": null}, {"column": "SamplingMethod", "alias": null}, {"column": "AnalysisMethod", "alias": null}, {"column": "Compartment", "alias": null}, {"column": "ResultTime", "alias": null}, {"column": "Quantity", "alias": null}, {"column": "TaxonType", "alias": null}, {"column": "TaxonRank", "alias": null}, {"column": "TaxonGroup", "alias": null}, {"column": "TaxonNameNl", "alias": null}, {"column": "ParameterType", "alias": null}, {"column": "Behaviour", "alias": null}, {"column": "Sampler", "alias": null}, {"column": "Completeness", "alias": null}, {"column": "Statistic", "alias": null}, {"column": "RecordingMethod", "alias": null}, {"column": "KrwCode", "alias": null}, {"column": "Purpose", "alias": null}, {"column": "Source", "alias": null}, {"column": "MeasurementPackage", "alias": null}, {"column": "MonitoringNetworks", "alias": null}, {"column": "longitude", "alias": null}, {"column": "latitude", "alias": null}], "filters": [], "output": {"format": "parquet"}}

# %%
df_aquadesk
# Out:
#         Organisation Supplier Projects  Code                    Description  \
# 0                RWS     None     None  WG17                       Balgzand
# 1                RWS     None     None  WG17                       Balgzand
# 2                RWS     None     None  WG17                       Balgzand
# 3                RWS     None     None  WG17                       Balgzand
# 4                RWS     None     None  WG17                       Balgzand
# ...              ...      ...      ...   ...                            ...
# 5167380          RWS     None     None  IJ15  Houtribdijk (IJsselmeerzijde)
# 5167381          RWS     None     None  IJ15  Houtribdijk (IJsselmeerzijde)
# 5167382          RWS     None     None  IJ15  Houtribdijk (IJsselmeerzijde)
# 5167383          RWS     None     None  IJ15  Houtribdijk (IJsselmeerzijde)
# 5167384          RWS     None     None  IJ15  Houtribdijk (IJsselmeerzijde)
#
#                   Parameter LifeForm  Value   Uom   Count   Type  ResultOf  \
# 0         Numenius phaeopus     None    NaN  None     3.0  Count  observed
# 1          Numenius arquata     None    NaN  None  1140.0  Count  observed
# 2         Tringa erythropus     None    NaN  None    79.0  Count  observed
# 3            Tringa totanus     None    NaN  None   344.0  Count  observed
# 4          Tringa nebularia     None    NaN  None     8.0  Count  observed
# ...                     ...      ...    ...   ...     ...    ...       ...
# 5167380    Larus argentatus     None    NaN  None    63.0  Count  observed
# 5167381       Larus marinus     None    NaN  None    21.0  Count  observed
# 5167382  Podiceps cristatus     None    NaN  None     8.0  Count  observed
# 5167383       Aythya ferina     None    NaN  None    50.0  Count  observed
# 5167384     Aythya fuligula     None    NaN  None  1385.0  Count  observed
#
#         SamplingMethod AnalysisMethod Compartment            ResultTime  \
# 0                 None           None          NT  1990-12-31T23:00:00Z
# 1                 None           None          NT  1990-12-31T23:00:00Z
# 2                 None           None          NT  1990-12-31T23:00:00Z
# 3                 None           None          NT  1990-12-31T23:00:00Z
# 4                 None           None          NT  1990-12-31T23:00:00Z
# ...                ...            ...         ...                   ...
# 5167380           None           None          NT  1993-12-31T23:00:00Z
# 5167381           None           None          NT  1993-12-31T23:00:00Z
# 5167382           None           None          NT  1993-12-31T23:00:00Z
# 5167383           None           None          NT  1993-12-31T23:00:00Z
# 5167384           None           None          NT  1993-12-31T23:00:00Z
#
#         Quantity TaxonType TaxonRank TaxonGroup        TaxonNameNl  \
# 0          AANTL     VOGLS   Species       None          Regenwulp
# 1          AANTL     VOGLS   Species       None               Wulp
# 2          AANTL     VOGLS   Species       None      Zwarte Ruiter
# 3          AANTL     VOGLS   Species       None           Tureluur
# 4          AANTL     VOGLS   Species       None    Groenpootruiter
# ...          ...       ...       ...        ...                ...
# 5167380    AANTL     VOGLS   Species       None        Zilvermeeuw
# 5167381    AANTL     VOGLS   Species       None  Grote mantelmeeuw
# 5167382    AANTL     VOGLS   Species       None               Fuut
# 5167383    AANTL     VOGLS   Species       None          Tafeleend
# 5167384    AANTL     VOGLS   Species       None           Kuifeend
#
#         ParameterType Behaviour Sampler Completeness Statistic  \
# 0          Biological      FOER   Sovon     COMPLETE      None
# 1          Biological      FOER   Sovon     COMPLETE      None
# 2          Biological      FOER   Sovon     COMPLETE      None
# 3          Biological      FOER   Sovon     COMPLETE      None
# 4          Biological      FOER   Sovon     COMPLETE      None
# ...               ...       ...     ...          ...       ...
# 5167380    Biological      FOER   Sovon     COMPLETE      None
# 5167381    Biological      FOER   Sovon     COMPLETE      None
# 5167382    Biological      FOER   Sovon     COMPLETE      None
# 5167383    Biological      FOER   Sovon     COMPLETE      None
# 5167384    Biological      FOER   Sovon     COMPLETE      None
#
#         RecordingMethod KrwCode Purpose Source MeasurementPackage  \
# 0                  None    None    None  Sovon               None
# 1                  None    None    None  Sovon               None
# 2                  None    None    None  Sovon               None
# 3                  None    None    None  Sovon               None
# 4                  None    None    None  Sovon               None
# ...                 ...     ...     ...    ...                ...
# 5167380            None    None    None  Sovon               None
# 5167381            None    None    None  Sovon               None
# 5167382            None    None    None  Sovon               None
# 5167383            None    None    None  Sovon               None
# 5167384            None    None    None  Sovon               None
#
#         MonitoringNetworks  longitude   latitude
# 0                     None   4.834411  52.916400
# 1                     None   4.834411  52.916400
# 2                     None   4.834411  52.916400
# 3                     None   4.834411  52.916400
# 4                     None   4.834411  52.916400
# ...                    ...        ...        ...
# 5167380               None   5.409417  52.628275
# 5167381               None   5.409417  52.628275
# 5167382               None   5.409417  52.628275
# 5167383               None   5.409417  52.628275
# 5167384               None   5.409417  52.628275
#
# [5167385 rows x 34 columns]

# %% [markdown]
# Nu er een beter beeld is van de Aquadesk content en er meer informatie beschikbaar is voor de kolommen, kan er worden geprobeerd om een mapping te maken naar DarwinCore. Om een logische data export na te bootsen zoals data normaal gesproken naar Eurobis Darwin Core zou worden geschreven is er gekozen om te focussen op exports voor twee taxon categorieën, Phytoplankton en Zoöplankton, waarvoor alle beschikbare data en metadata is opgehaald (zie tabellen hieronder).
#
# Daarbij is er ook een mapping toegevoegd van de WORMS taxon-categorieën. Om dat te realiseren is er een data dump aangevraagd van gehele taxonomy van de WORMS catalogus en deze gebruikt om op basis van de “scientific name” de bijbehorende mapping naar Genus, Species, Family te doen en deze als kolommen toe te voegen.

# %%
df_FYTPT = df_aquadesk[df_aquadesk['TaxonType'] == 'FYTPT']
df_FYTPT = df_FYTPT.reset_index(drop=True)
df_FYTPT
# Out:
#        Organisation Supplier    Projects        Code Description  \
# 0               RWS      RWS  MWTL_FYTPT  NRDZE_0012   NOORDWK10
# 1               RWS      RWS  MWTL_FYTPT  NRDZE_0012   NOORDWK10
# 2               RWS      RWS  MWTL_FYTPT  NRDZE_0012   NOORDWK10
# 3               RWS      RWS  MWTL_FYTPT  NRDZE_0012   NOORDWK10
# 4               RWS      RWS  MWTL_FYTPT  NRDZE_0012   NOORDWK10
# ...             ...      ...         ...         ...         ...
# 575995          RWS      RWS  MWTL_FYTPT  NRDZE_0012   NOORDWK10
# 575996          RWS      RWS  MWTL_FYTPT  NRDZE_0012   NOORDWK10
# 575997          RWS      RWS  MWTL_FYTPT  NRDZE_0012   NOORDWK10
# 575998          RWS      RWS  MWTL_FYTPT  NRDZE_0012   NOORDWK10
# 575999          RWS      RWS  MWTL_FYTPT  NRDZE_0012   NOORDWK10
#
#                  Parameter LifeForm      Value   Uom  Count     Type  \
# 0       Gyrodinium spirale   LV-CEL        NaN  None    1.0  Measure
# 1              Heterocapsa   LV-CEL     9799.0   N/L    NaN    Count
# 2              Heterocapsa   LV-CEL        NaN  None    2.0  Measure
# 3                 Khakista   LV-CEL   497225.0   N/L    NaN    Count
# 4                 Khakista   LV-CEL        NaN  None   23.0  Measure
# ...                    ...      ...        ...   ...    ...      ...
# 575995           Eukaryota   LV-CEL  1131221.0   N/L    NaN    Count
# 575996           Eukaryota   LV-CEL        NaN  None    5.0  Measure
# 575997   Gymnodiniales [1]   LV-CEL    64975.0   N/L    NaN    Count
# 575998   Gymnodiniales [1]   LV-CEL        NaN  None    5.0  Measure
# 575999  Gyrodinium spirale   LV-CEL     4899.0   N/L    NaN    Count
#
#              ResultOf SamplingMethod AnalysisMethod Compartment  \
# 0         observation     FYTPT_S521     FYTPT_A523          OW
# 1       extrapolation     FYTPT_S521     FYTPT_A523          OW
# 2         observation     FYTPT_S521     FYTPT_A523          OW
# 3       extrapolation     FYTPT_S521     FYTPT_A523          OW
# 4         observation     FYTPT_S521     FYTPT_A523          OW
# ...               ...            ...            ...         ...
# 575995  extrapolation     FYTPT_S521     FYTPT_A523          OW
# 575996    observation     FYTPT_S521     FYTPT_A523          OW
# 575997  extrapolation     FYTPT_S521     FYTPT_A523          OW
# 575998    observation     FYTPT_S521     FYTPT_A523          OW
# 575999  extrapolation     FYTPT_S521     FYTPT_A523          OW
#
#                   ResultTime   Quantity TaxonType  TaxonRank TaxonGroup  \
# 0       2010-09-12T22:00:00Z  AANTPVLME     FYTPT    Species      DINOF
# 1       2010-09-12T22:00:00Z  AANTPVLME     FYTPT      Genus      DINOF
# 2       2010-09-12T22:00:00Z  AANTPVLME     FYTPT      Genus      DINOF
# 3       2010-09-12T22:00:00Z  AANTPVLME     FYTPT  Subphylum      HITAX
# 4       2010-09-12T22:00:00Z  AANTPVLME     FYTPT  Subphylum      HITAX
# ...                      ...        ...       ...        ...        ...
# 575995  2010-09-12T22:00:00Z  AANTPVLME     FYTPT     Domain      HITAX
# 575996  2010-09-12T22:00:00Z  AANTPVLME     FYTPT     Domain      HITAX
# 575997  2010-09-12T22:00:00Z  AANTPVLME     FYTPT      Order      HITAX
# 575998  2010-09-12T22:00:00Z  AANTPVLME     FYTPT      Order      HITAX
# 575999  2010-09-12T22:00:00Z  AANTPVLME     FYTPT    Species      DINOF
#
#        TaxonNameNl ParameterType Behaviour Sampler Completeness Statistic  \
# 0             None          None      None    None         None      None
# 1             None          None      None    None         None      None
# 2             None          None      None    None         None      None
# 3             None          None      None    None         None      None
# 4             None          None      None    None         None      None
# ...            ...           ...       ...     ...          ...       ...
# 575995        None          None      None    None         None      None
# 575996        None          None      None    None         None      None
# 575997        None          None      None    None         None      None
# 575998        None          None      None    None         None      None
# 575999        None          None      None    None         None      None
#
#        RecordingMethod KrwCode Purpose    Source MeasurementPackage  \
# 0                 None    None      MT  AquaDesk              FP.AC
# 1                 None    None      MT  AquaDesk              FP.AC
# 2                 None    None      MT  AquaDesk              FP.AC
# 3                 None    None      MT  AquaDesk              FP.AC
# 4                 None    None      MT  AquaDesk              FP.AC
# ...                ...     ...     ...       ...                ...
# 575995            None    None      MT  AquaDesk              FP.AC
# 575996            None    None      MT  AquaDesk              FP.AC
# 575997            None    None      MT  AquaDesk              FP.AC
# 575998            None    None      MT  AquaDesk              FP.AC
# 575999            None    None      MT  AquaDesk              FP.AC
#
#        MonitoringNetworks  longitude  latitude
# 0                 ['MRN']    4.30116  52.30143
# 1                 ['MRN']    4.30116  52.30143
# 2                 ['MRN']    4.30116  52.30143
# 3                 ['MRN']    4.30116  52.30143
# 4                 ['MRN']    4.30116  52.30143
# ...                   ...        ...       ...
# 575995            ['MRN']    4.30116  52.30143
# 575996            ['MRN']    4.30116  52.30143
# 575997            ['MRN']    4.30116  52.30143
# 575998            ['MRN']    4.30116  52.30143
# 575999            ['MRN']    4.30116  52.30143
#
# [576000 rows x 34 columns]

# %%
df_ZOOPT = df_aquadesk[df_aquadesk['TaxonType'] == 'ZOOPT']
df_ZOOPT = df_ZOOPT.reset_index(drop=True)
df_ZOOPT
# Out:
#       Organisation Supplier    Projects        Code  Description  \
# 0              RWS      RWS  MWTL_FYTPT  NRDZE_0012    NOORDWK10
# 1              RWS      RWS  MWTL_FYTPT  NRDZE_0012    NOORDWK10
# 2              RWS      RWS  MWTL_FYTPT  NRDZE_0012    NOORDWK10
# 3              RWS      RWS  MWTL_FYTPT  NRDZE_0012    NOORDWK10
# 4              RWS      RWS  MWTL_FYTPT  NRDZE_0012    NOORDWK10
# ...            ...      ...         ...         ...          ...
# 19999          RWS      RWS        KIMA  MRKMR_8176  MKWDDN_8856
# 20000          RWS      RWS        KIMA  MRKMR_8176  MKWDDN_8856
# 20001          RWS      RWS        KIMA  MRKMR_8176  MKWDDN_8856
# 20002          RWS      RWS        KIMA  MRKMR_8176  MKWDDN_8856
# 20003          RWS      RWS        KIMA  MRKMR_8176  MKWDDN_8856
#
#                 Parameter LifeForm         Value   Uom  Count     Type  \
# 0        Myrionecta rubra   LV-CEL   1600.000000   N/L    NaN    Count
# 1        Myrionecta rubra   LV-CEL           NaN  None    2.0  Measure
# 2        Myrionecta rubra   LV-CEL  10796.000000   N/L    NaN    Count
# 3        Myrionecta rubra   LV-CEL           NaN  None    2.0  Measure
# 4        Myrionecta rubra   LV-CEL   2400.000000   N/L    NaN    Count
# ...                   ...      ...           ...   ...    ...      ...
# 19999  Eubosmina coregoni     None           NaN  None    0.0  Measure
# 20000            Copepoda     None     24.414522  UG/L    NaN    Count
# 20001            Copepoda     None           NaN  None   18.0  Measure
# 20002            Copepoda     None      6.154490  UG/L    NaN    Count
# 20003            Copepoda     None           NaN  None    1.0  Measure
#
#             ResultOf SamplingMethod AnalysisMethod Compartment  \
# 0      extrapolation     FYTPT_S523     FYTPT_A011          OW
# 1        observation     FYTPT_S523     FYTPT_A011          OW
# 2      extrapolation     FYTPT_S523     FYTPT_A011          OW
# 3        observation     FYTPT_S523     FYTPT_A011          OW
# 4      extrapolation     FYTPT_S523     FYTPT_A011          OW
# ...              ...            ...            ...         ...
# 19999    observation      ZOOPT_001    ZOOPT_RWS01          OW
# 20000  extrapolation      ZOOPT_001    ZOOPT_RWS01          OW
# 20001    observation      ZOOPT_001    ZOOPT_RWS01          OW
# 20002  extrapolation      ZOOPT_001    ZOOPT_RWS01          OW
# 20003    observation      ZOOPT_001    ZOOPT_RWS01          OW
#
#                  ResultTime   Quantity TaxonType TaxonRank TaxonGroup  \
# 0      2018-06-11T22:00:00Z  AANTPVLME     ZOOPT   Species      CILIO
# 1      2018-06-11T22:00:00Z  AANTPVLME     ZOOPT   Species      CILIO
# 2      2018-07-03T22:00:00Z  AANTPVLME     ZOOPT   Species      CILIO
# 3      2018-07-03T22:00:00Z  AANTPVLME     ZOOPT   Species      CILIO
# 4      2018-07-15T22:00:00Z  AANTPVLME     ZOOPT   Species      CILIO
# ...                     ...        ...       ...       ...        ...
# 19999  2024-10-07T22:00:00Z    CONCTTE     ZOOPT   Species      BRANC
# 20000  2024-10-07T22:00:00Z    CONCTTE     ZOOPT  Subclass      COPEP
# 20001  2024-10-07T22:00:00Z    CONCTTE     ZOOPT  Subclass      COPEP
# 20002  2024-10-07T22:00:00Z    CONCTTE     ZOOPT  Subclass      COPEP
# 20003  2024-10-07T22:00:00Z    CONCTTE     ZOOPT  Subclass      COPEP
#
#              TaxonNameNl ParameterType Behaviour Sampler Completeness  \
# 0                   None          None      None    None         None
# 1                   None          None      None    None         None
# 2                   None          None      None    None         None
# 3                   None          None      None    None         None
# 4                   None          None      None    None         None
# ...                  ...           ...       ...     ...          ...
# 19999  Langslurfwatervlo          None      None    None         None
# 20000               None          None      None    None         None
# 20001               None          None      None    None         None
# 20002               None          None      None    None         None
# 20003               None          None      None    None         None
#
#       Statistic RecordingMethod KrwCode Purpose    Source MeasurementPackage  \
# 0          None            None    None      MT  AquaDesk              ZP.AB
# 1          None            None    None      MT  AquaDesk              ZP.AB
# 2          None            None    None      MT  AquaDesk              ZP.AB
# 3          None            None    None      MT  AquaDesk              ZP.AB
# 4          None            None    None      MT  AquaDesk              ZP.AB
# ...         ...             ...     ...     ...       ...                ...
# 19999      None            None    None      KT  AquaDesk              ZP.MS
# 20000      None            None    None      KT  AquaDesk              ZP.MS
# 20001      None            None    None      KT  AquaDesk              ZP.MS
# 20002      None            None    None      KT  AquaDesk              ZP.MS
# 20003      None            None    None      KT  AquaDesk              ZP.MS
#
#       MonitoringNetworks  longitude  latitude
# 0                ['MRN']    4.30116  52.30143
# 1                ['MRN']    4.30116  52.30143
# 2                ['MRN']    4.30116  52.30143
# 3                ['MRN']    4.30116  52.30143
# 4                ['MRN']    4.30116  52.30143
# ...                  ...        ...       ...
# 19999           ['KIMA']    5.37176  52.58940
# 20000           ['KIMA']    5.37176  52.58940
# 20001           ['KIMA']    5.37176  52.58940
# 20002           ['KIMA']    5.37176  52.58940
# 20003           ['KIMA']    5.37176  52.58940
#
# [20004 rows x 34 columns]

# %% [markdown]
# Om in een later stadium te kunnen onderzoeken hoe de metadata en data kunnen worden gemapped voor publicatie in Eurobis Darwin Core standaard is er eerst zoveel mogelijk informatie nodig over de inhoud van de Aquadesk kolommen. Met de informatie die via de V2 beschikbaar is, is er een poging gedaan om zoveel mogelijk informatie die in de dataframes staat toe te lichten.

# %%
with open("Grootheid_Code.csv", newline="", encoding="utf-8") as csvfile:
    reader = csv.reader(csvfile)  
    mapping_dict = {code: explanation for code, explanation, _ in reader}

df_aquadesk["Quantity_explanation"] = df_aquadesk["Quantity"].map(mapping_dict)

# %%
with open("Compartiment_Code.csv", newline="", encoding="utf-8") as csvfile:
    reader = csv.reader(csvfile)  
    mapping_dict = {code: explanation for code, explanation, _ in reader}

df_aquadesk["Compartment_explanation"] = df_aquadesk["Compartment"].map(mapping_dict)

# %%
df_aquadesk["license"] = ""
df_aquadesk['language'] = 'en'
df_aquadesk
# Out:
#         Organisation Supplier Projects  Code                    Description  \
# 0                RWS     None     None  WG17                       Balgzand
# 1                RWS     None     None  WG17                       Balgzand
# 2                RWS     None     None  WG17                       Balgzand
# 3                RWS     None     None  WG17                       Balgzand
# 4                RWS     None     None  WG17                       Balgzand
# ...              ...      ...      ...   ...                            ...
# 5167380          RWS     None     None  IJ15  Houtribdijk (IJsselmeerzijde)
# 5167381          RWS     None     None  IJ15  Houtribdijk (IJsselmeerzijde)
# 5167382          RWS     None     None  IJ15  Houtribdijk (IJsselmeerzijde)
# 5167383          RWS     None     None  IJ15  Houtribdijk (IJsselmeerzijde)
# 5167384          RWS     None     None  IJ15  Houtribdijk (IJsselmeerzijde)
#
#                   Parameter LifeForm  Value   Uom   Count   Type  ResultOf  \
# 0         Numenius phaeopus     None    NaN  None     3.0  Count  observed
# 1          Numenius arquata     None    NaN  None  1140.0  Count  observed
# 2         Tringa erythropus     None    NaN  None    79.0  Count  observed
# 3            Tringa totanus     None    NaN  None   344.0  Count  observed
# 4          Tringa nebularia     None    NaN  None     8.0  Count  observed
# ...                     ...      ...    ...   ...     ...    ...       ...
# 5167380    Larus argentatus     None    NaN  None    63.0  Count  observed
# 5167381       Larus marinus     None    NaN  None    21.0  Count  observed
# 5167382  Podiceps cristatus     None    NaN  None     8.0  Count  observed
# 5167383       Aythya ferina     None    NaN  None    50.0  Count  observed
# 5167384     Aythya fuligula     None    NaN  None  1385.0  Count  observed
#
#         SamplingMethod AnalysisMethod Compartment            ResultTime  \
# 0                 None           None          NT  1990-12-31T23:00:00Z
# 1                 None           None          NT  1990-12-31T23:00:00Z
# 2                 None           None          NT  1990-12-31T23:00:00Z
# 3                 None           None          NT  1990-12-31T23:00:00Z
# 4                 None           None          NT  1990-12-31T23:00:00Z
# ...                ...            ...         ...                   ...
# 5167380           None           None          NT  1993-12-31T23:00:00Z
# 5167381           None           None          NT  1993-12-31T23:00:00Z
# 5167382           None           None          NT  1993-12-31T23:00:00Z
# 5167383           None           None          NT  1993-12-31T23:00:00Z
# 5167384           None           None          NT  1993-12-31T23:00:00Z
#
#         Quantity TaxonType TaxonRank TaxonGroup        TaxonNameNl  \
# 0          AANTL     VOGLS   Species       None          Regenwulp
# 1          AANTL     VOGLS   Species       None               Wulp
# 2          AANTL     VOGLS   Species       None      Zwarte Ruiter
# 3          AANTL     VOGLS   Species       None           Tureluur
# 4          AANTL     VOGLS   Species       None    Groenpootruiter
# ...          ...       ...       ...        ...                ...
# 5167380    AANTL     VOGLS   Species       None        Zilvermeeuw
# 5167381    AANTL     VOGLS   Species       None  Grote mantelmeeuw
# 5167382    AANTL     VOGLS   Species       None               Fuut
# 5167383    AANTL     VOGLS   Species       None          Tafeleend
# 5167384    AANTL     VOGLS   Species       None           Kuifeend
#
#         ParameterType Behaviour Sampler Completeness Statistic  \
# 0          Biological      FOER   Sovon     COMPLETE      None
# 1          Biological      FOER   Sovon     COMPLETE      None
# 2          Biological      FOER   Sovon     COMPLETE      None
# 3          Biological      FOER   Sovon     COMPLETE      None
# 4          Biological      FOER   Sovon     COMPLETE      None
# ...               ...       ...     ...          ...       ...
# 5167380    Biological      FOER   Sovon     COMPLETE      None
# 5167381    Biological      FOER   Sovon     COMPLETE      None
# 5167382    Biological      FOER   Sovon     COMPLETE      None
# 5167383    Biological      FOER   Sovon     COMPLETE      None
# 5167384    Biological      FOER   Sovon     COMPLETE      None
#
#         RecordingMethod KrwCode Purpose Source MeasurementPackage  \
# 0                  None    None    None  Sovon               None
# 1                  None    None    None  Sovon               None
# 2                  None    None    None  Sovon               None
# 3                  None    None    None  Sovon               None
# 4                  None    None    None  Sovon               None
# ...                 ...     ...     ...    ...                ...
# 5167380            None    None    None  Sovon               None
# 5167381            None    None    None  Sovon               None
# 5167382            None    None    None  Sovon               None
# 5167383            None    None    None  Sovon               None
# 5167384            None    None    None  Sovon               None
#
#         MonitoringNetworks  longitude   latitude Quantity_explanation  \
# 0                     None   4.834411  52.916400               Aantal
# 1                     None   4.834411  52.916400               Aantal
# 2                     None   4.834411  52.916400               Aantal
# 3                     None   4.834411  52.916400               Aantal
# 4                     None   4.834411  52.916400               Aantal
# ...                    ...        ...        ...                  ...
# 5167380               None   5.409417  52.628275               Aantal
# 5167381               None   5.409417  52.628275               Aantal
# 5167382               None   5.409417  52.628275               Aantal
# 5167383               None   5.409417  52.628275               Aantal
# 5167384               None   5.409417  52.628275               Aantal
#
#         Compartment_explanation license language
# 0           Niet van toepassing               en
# 1           Niet van toepassing               en
# 2           Niet van toepassing               en
# 3           Niet van toepassing               en
# 4           Niet van toepassing               en
# ...                         ...     ...      ...
# 5167380     Niet van toepassing               en
# 5167381     Niet van toepassing               en
# 5167382     Niet van toepassing               en
# 5167383     Niet van toepassing               en
# 5167384     Niet van toepassing               en
#
# [5167385 rows x 38 columns]

# %% [markdown]
# Voor beide categorieën is er een poging gedaan om de kolomnamen te mappen naar DarwinCore velden: https://dwc.tdwg.org/terms/. In het geval van Aquadesk gaat het uitsluitend om aantallen (of dichtheden) van biologische waarnemingen, waardoor het dus hoofdzakelijk onder de Occurrence type record valt met eventueel wat Event-metadata erbij waarvoor eerder de belangrijkste Darwin Core elementen zijn genoteerd. Dit betekent dat een DarwinCore Aquadesk dataset (.zip) als volgt kan worden ingedeeld:
# - event.txt (waar en wanneer is het monster genomen)
# - occurrence.txt (wat is er gemeten)
# - meta.xml
# - eml.xml
#
# Om tot deze DarwinCore Aquadesk datasets te kunnen komen, moeten we onderzoeken of we voor de event en occurrence type record de “required” velden dekken. Als we de DarwinCore elementen van de bovenstaande tabellen filteren voor “Event” en “Occurrence” komen we op de volgende elementen uit als "Essentieel".
#
# Event
# - eventDate, eventID, decimalLongitude, decimalLatitude
#
# Occurrence
# - eventDate, decimalLongitude, decimalLatitude, occurrenceID, scientificName, occurrenceStatus, basisOfRecord
#
# Om te kijken of we deze DarwinCore elementen kunnen mappen aan de Aquadesk data, is er een poging gedaan om alle kolomnamen te mappen naar relevante DarwinCore elementen. Onderstaande tabellen geven voor een deel van de kolommen voor Phytoplankton en Zoöplankton een eerste draft van mogelijke DarwinCore kolomnamen. Dit moet nog verder worden onderzocht en zal nog veel aanpassingen omvatten.

# %%
aquadesk_to_dwc = {
    "Supplier": "recordedBy",
    "Projects": "datasetID",
    "Code": "occurrenceID",
    "Description": "locality",
    "Parameter": "scientificName",
    "LifeForm": "lifeStage",
    "Value": "organismQuantity",
    "Count": "organismQuantity2",
    "Uom": "measurementUnit",
    "Type": "measurementType",
    "ResultOf": "basisOfRecord",
    'SamplingMethod' : 'samplingProtocol',
    'AnalysisMethod': "measurementMethod",
    'Compartment_explanation' : 'habitat',
    "ResultTime": "eventDate",  
    "Quantity_explanation": "organismQuantityType",
    "TaxonType": "organismRemarks",
    "TaxonGroup": "taxonRemarks",
    "TaxonRank": "taxonRank",
    "MeasurementPackage": "measurementRemarks",
    "MonitoringNetworks": "locationRemarks",
    "license": "license",
    "language": "language",
    "longitude": "decimalLongitude",
    "latitude": "decimalLatitude"
}

dwc_columns = list(aquadesk_to_dwc.values())
df_dwc = df_aquadesk.rename(columns=aquadesk_to_dwc)[dwc_columns]

column_order = [
    "eventDate",
    "decimalLongitude",
    "decimalLatitude",
    "scientificName",
    "organismQuantity2",
    "basisOfRecord",
    "datasetID",
    "occurrenceID",
    "recordedBy",
    "organismQuantity",
    "measurementUnit",
    "measurementType",
    "samplingProtocol",
    "measurementMethod",
    "habitat",
    "lifeStage",
    "organismQuantityType",
    "organismRemarks",
    "taxonRemarks",
    "taxonRank",
    "measurementRemarks",
    "locationRemarks",
    "locality",
    "license",
    "language"
]

df_dwc = df_dwc[column_order]
df_dwc
# Out:
#                     eventDate  decimalLongitude  decimalLatitude  \
# 0        1990-12-31T23:00:00Z          4.834411        52.916400
# 1        1990-12-31T23:00:00Z          4.834411        52.916400
# 2        1990-12-31T23:00:00Z          4.834411        52.916400
# 3        1990-12-31T23:00:00Z          4.834411        52.916400
# 4        1990-12-31T23:00:00Z          4.834411        52.916400
# ...                       ...               ...              ...
# 5167380  1993-12-31T23:00:00Z          5.409417        52.628275
# 5167381  1993-12-31T23:00:00Z          5.409417        52.628275
# 5167382  1993-12-31T23:00:00Z          5.409417        52.628275
# 5167383  1993-12-31T23:00:00Z          5.409417        52.628275
# 5167384  1993-12-31T23:00:00Z          5.409417        52.628275
#
#              scientificName  organismQuantity2 basisOfRecord datasetID  \
# 0         Numenius phaeopus                3.0      observed      None
# 1          Numenius arquata             1140.0      observed      None
# 2         Tringa erythropus               79.0      observed      None
# 3            Tringa totanus              344.0      observed      None
# 4          Tringa nebularia                8.0      observed      None
# ...                     ...                ...           ...       ...
# 5167380    Larus argentatus               63.0      observed      None
# 5167381       Larus marinus               21.0      observed      None
# 5167382  Podiceps cristatus                8.0      observed      None
# 5167383       Aythya ferina               50.0      observed      None
# 5167384     Aythya fuligula             1385.0      observed      None
#
#         occurrenceID recordedBy  organismQuantity measurementUnit  \
# 0               WG17       None               NaN            None
# 1               WG17       None               NaN            None
# 2               WG17       None               NaN            None
# 3               WG17       None               NaN            None
# 4               WG17       None               NaN            None
# ...              ...        ...               ...             ...
# 5167380         IJ15       None               NaN            None
# 5167381         IJ15       None               NaN            None
# 5167382         IJ15       None               NaN            None
# 5167383         IJ15       None               NaN            None
# 5167384         IJ15       None               NaN            None
#
#         measurementType samplingProtocol measurementMethod  \
# 0                 Count             None              None
# 1                 Count             None              None
# 2                 Count             None              None
# 3                 Count             None              None
# 4                 Count             None              None
# ...                 ...              ...               ...
# 5167380           Count             None              None
# 5167381           Count             None              None
# 5167382           Count             None              None
# 5167383           Count             None              None
# 5167384           Count             None              None
#
#                      habitat lifeStage organismQuantityType organismRemarks  \
# 0        Niet van toepassing      None               Aantal           VOGLS
# 1        Niet van toepassing      None               Aantal           VOGLS
# 2        Niet van toepassing      None               Aantal           VOGLS
# 3        Niet van toepassing      None               Aantal           VOGLS
# 4        Niet van toepassing      None               Aantal           VOGLS
# ...                      ...       ...                  ...             ...
# 5167380  Niet van toepassing      None               Aantal           VOGLS
# 5167381  Niet van toepassing      None               Aantal           VOGLS
# 5167382  Niet van toepassing      None               Aantal           VOGLS
# 5167383  Niet van toepassing      None               Aantal           VOGLS
# 5167384  Niet van toepassing      None               Aantal           VOGLS
#
#         taxonRemarks taxonRank measurementRemarks locationRemarks  \
# 0               None   Species               None            None
# 1               None   Species               None            None
# 2               None   Species               None            None
# 3               None   Species               None            None
# 4               None   Species               None            None
# ...              ...       ...                ...             ...
# 5167380         None   Species               None            None
# 5167381         None   Species               None            None
# 5167382         None   Species               None            None
# 5167383         None   Species               None            None
# 5167384         None   Species               None            None
#
#                               locality license language
# 0                             Balgzand               en
# 1                             Balgzand               en
# 2                             Balgzand               en
# 3                             Balgzand               en
# 4                             Balgzand               en
# ...                                ...     ...      ...
# 5167380  Houtribdijk (IJsselmeerzijde)               en
# 5167381  Houtribdijk (IJsselmeerzijde)               en
# 5167382  Houtribdijk (IJsselmeerzijde)               en
# 5167383  Houtribdijk (IJsselmeerzijde)               en
# 5167384  Houtribdijk (IJsselmeerzijde)               en
#
# [5167385 rows x 25 columns]

# %%
df_FYTPT = df_dwc[df_dwc['organismRemarks'] == 'FYTPT']
df_FYTPT = df_FYTPT.reset_index(drop=True)
df_FYTPT
# Out:
#                    eventDate  decimalLongitude  decimalLatitude  \
# 0       2010-09-12T22:00:00Z           4.30116         52.30143
# 1       2010-09-12T22:00:00Z           4.30116         52.30143
# 2       2010-09-12T22:00:00Z           4.30116         52.30143
# 3       2010-09-12T22:00:00Z           4.30116         52.30143
# 4       2010-09-12T22:00:00Z           4.30116         52.30143
# ...                      ...               ...              ...
# 575995  2010-09-12T22:00:00Z           4.30116         52.30143
# 575996  2010-09-12T22:00:00Z           4.30116         52.30143
# 575997  2010-09-12T22:00:00Z           4.30116         52.30143
# 575998  2010-09-12T22:00:00Z           4.30116         52.30143
# 575999  2010-09-12T22:00:00Z           4.30116         52.30143
#
#             scientificName  organismQuantity2  basisOfRecord   datasetID  \
# 0       Gyrodinium spirale                1.0    observation  MWTL_FYTPT
# 1              Heterocapsa                NaN  extrapolation  MWTL_FYTPT
# 2              Heterocapsa                2.0    observation  MWTL_FYTPT
# 3                 Khakista                NaN  extrapolation  MWTL_FYTPT
# 4                 Khakista               23.0    observation  MWTL_FYTPT
# ...                    ...                ...            ...         ...
# 575995           Eukaryota                NaN  extrapolation  MWTL_FYTPT
# 575996           Eukaryota                5.0    observation  MWTL_FYTPT
# 575997   Gymnodiniales [1]                NaN  extrapolation  MWTL_FYTPT
# 575998   Gymnodiniales [1]                5.0    observation  MWTL_FYTPT
# 575999  Gyrodinium spirale                NaN  extrapolation  MWTL_FYTPT
#
#        occurrenceID recordedBy  organismQuantity measurementUnit  \
# 0        NRDZE_0012        RWS               NaN            None
# 1        NRDZE_0012        RWS            9799.0             N/L
# 2        NRDZE_0012        RWS               NaN            None
# 3        NRDZE_0012        RWS          497225.0             N/L
# 4        NRDZE_0012        RWS               NaN            None
# ...             ...        ...               ...             ...
# 575995   NRDZE_0012        RWS         1131221.0             N/L
# 575996   NRDZE_0012        RWS               NaN            None
# 575997   NRDZE_0012        RWS           64975.0             N/L
# 575998   NRDZE_0012        RWS               NaN            None
# 575999   NRDZE_0012        RWS            4899.0             N/L
#
#        measurementType samplingProtocol measurementMethod           habitat  \
# 0              Measure       FYTPT_S521        FYTPT_A523  Oppervlaktewater
# 1                Count       FYTPT_S521        FYTPT_A523  Oppervlaktewater
# 2              Measure       FYTPT_S521        FYTPT_A523  Oppervlaktewater
# 3                Count       FYTPT_S521        FYTPT_A523  Oppervlaktewater
# 4              Measure       FYTPT_S521        FYTPT_A523  Oppervlaktewater
# ...                ...              ...               ...               ...
# 575995           Count       FYTPT_S521        FYTPT_A523  Oppervlaktewater
# 575996         Measure       FYTPT_S521        FYTPT_A523  Oppervlaktewater
# 575997           Count       FYTPT_S521        FYTPT_A523  Oppervlaktewater
# 575998         Measure       FYTPT_S521        FYTPT_A523  Oppervlaktewater
# 575999           Count       FYTPT_S521        FYTPT_A523  Oppervlaktewater
#
#        lifeStage organismQuantityType organismRemarks taxonRemarks  taxonRank  \
# 0         LV-CEL    Aantal per volume           FYTPT        DINOF    Species
# 1         LV-CEL    Aantal per volume           FYTPT        DINOF      Genus
# 2         LV-CEL    Aantal per volume           FYTPT        DINOF      Genus
# 3         LV-CEL    Aantal per volume           FYTPT        HITAX  Subphylum
# 4         LV-CEL    Aantal per volume           FYTPT        HITAX  Subphylum
# ...          ...                  ...             ...          ...        ...
# 575995    LV-CEL    Aantal per volume           FYTPT        HITAX     Domain
# 575996    LV-CEL    Aantal per volume           FYTPT        HITAX     Domain
# 575997    LV-CEL    Aantal per volume           FYTPT        HITAX      Order
# 575998    LV-CEL    Aantal per volume           FYTPT        HITAX      Order
# 575999    LV-CEL    Aantal per volume           FYTPT        DINOF    Species
#
#        measurementRemarks locationRemarks   locality license language
# 0                   FP.AC         ['MRN']  NOORDWK10               en
# 1                   FP.AC         ['MRN']  NOORDWK10               en
# 2                   FP.AC         ['MRN']  NOORDWK10               en
# 3                   FP.AC         ['MRN']  NOORDWK10               en
# 4                   FP.AC         ['MRN']  NOORDWK10               en
# ...                   ...             ...        ...     ...      ...
# 575995              FP.AC         ['MRN']  NOORDWK10               en
# 575996              FP.AC         ['MRN']  NOORDWK10               en
# 575997              FP.AC         ['MRN']  NOORDWK10               en
# 575998              FP.AC         ['MRN']  NOORDWK10               en
# 575999              FP.AC         ['MRN']  NOORDWK10               en
#
# [576000 rows x 25 columns]

# %%
df_ZOOPT = df_dwc[df_dwc['organismRemarks'] == 'ZOOPT']
df_ZOOPT = df_ZOOPT.reset_index(drop=True)
df_ZOOPT
# Out:
#                   eventDate  decimalLongitude  decimalLatitude  \
# 0      2018-06-11T22:00:00Z           4.30116         52.30143
# 1      2018-06-11T22:00:00Z           4.30116         52.30143
# 2      2018-07-03T22:00:00Z           4.30116         52.30143
# 3      2018-07-03T22:00:00Z           4.30116         52.30143
# 4      2018-07-15T22:00:00Z           4.30116         52.30143
# ...                     ...               ...              ...
# 19999  2024-10-07T22:00:00Z           5.37176         52.58940
# 20000  2024-10-07T22:00:00Z           5.37176         52.58940
# 20001  2024-10-07T22:00:00Z           5.37176         52.58940
# 20002  2024-10-07T22:00:00Z           5.37176         52.58940
# 20003  2024-10-07T22:00:00Z           5.37176         52.58940
#
#            scientificName  organismQuantity2  basisOfRecord   datasetID  \
# 0        Myrionecta rubra                NaN  extrapolation  MWTL_FYTPT
# 1        Myrionecta rubra                2.0    observation  MWTL_FYTPT
# 2        Myrionecta rubra                NaN  extrapolation  MWTL_FYTPT
# 3        Myrionecta rubra                2.0    observation  MWTL_FYTPT
# 4        Myrionecta rubra                NaN  extrapolation  MWTL_FYTPT
# ...                   ...                ...            ...         ...
# 19999  Eubosmina coregoni                0.0    observation        KIMA
# 20000            Copepoda                NaN  extrapolation        KIMA
# 20001            Copepoda               18.0    observation        KIMA
# 20002            Copepoda                NaN  extrapolation        KIMA
# 20003            Copepoda                1.0    observation        KIMA
#
#       occurrenceID recordedBy  organismQuantity measurementUnit  \
# 0       NRDZE_0012        RWS       1600.000000             N/L
# 1       NRDZE_0012        RWS               NaN            None
# 2       NRDZE_0012        RWS      10796.000000             N/L
# 3       NRDZE_0012        RWS               NaN            None
# 4       NRDZE_0012        RWS       2400.000000             N/L
# ...            ...        ...               ...             ...
# 19999   MRKMR_8176        RWS               NaN            None
# 20000   MRKMR_8176        RWS         24.414522            UG/L
# 20001   MRKMR_8176        RWS               NaN            None
# 20002   MRKMR_8176        RWS          6.154490            UG/L
# 20003   MRKMR_8176        RWS               NaN            None
#
#       measurementType samplingProtocol measurementMethod           habitat  \
# 0               Count       FYTPT_S523        FYTPT_A011  Oppervlaktewater
# 1             Measure       FYTPT_S523        FYTPT_A011  Oppervlaktewater
# 2               Count       FYTPT_S523        FYTPT_A011  Oppervlaktewater
# 3             Measure       FYTPT_S523        FYTPT_A011  Oppervlaktewater
# 4               Count       FYTPT_S523        FYTPT_A011  Oppervlaktewater
# ...               ...              ...               ...               ...
# 19999         Measure        ZOOPT_001       ZOOPT_RWS01  Oppervlaktewater
# 20000           Count        ZOOPT_001       ZOOPT_RWS01  Oppervlaktewater
# 20001         Measure        ZOOPT_001       ZOOPT_RWS01  Oppervlaktewater
# 20002           Count        ZOOPT_001       ZOOPT_RWS01  Oppervlaktewater
# 20003         Measure        ZOOPT_001       ZOOPT_RWS01  Oppervlaktewater
#
#       lifeStage organismQuantityType organismRemarks taxonRemarks taxonRank  \
# 0        LV-CEL    Aantal per volume           ZOOPT        CILIO   Species
# 1        LV-CEL    Aantal per volume           ZOOPT        CILIO   Species
# 2        LV-CEL    Aantal per volume           ZOOPT        CILIO   Species
# 3        LV-CEL    Aantal per volume           ZOOPT        CILIO   Species
# 4        LV-CEL    Aantal per volume           ZOOPT        CILIO   Species
# ...         ...                  ...             ...          ...       ...
# 19999      None         Concentratie           ZOOPT        BRANC   Species
# 20000      None         Concentratie           ZOOPT        COPEP  Subclass
# 20001      None         Concentratie           ZOOPT        COPEP  Subclass
# 20002      None         Concentratie           ZOOPT        COPEP  Subclass
# 20003      None         Concentratie           ZOOPT        COPEP  Subclass
#
#       measurementRemarks locationRemarks     locality license language
# 0                  ZP.AB         ['MRN']    NOORDWK10               en
# 1                  ZP.AB         ['MRN']    NOORDWK10               en
# 2                  ZP.AB         ['MRN']    NOORDWK10               en
# 3                  ZP.AB         ['MRN']    NOORDWK10               en
# 4                  ZP.AB         ['MRN']    NOORDWK10               en
# ...                  ...             ...          ...     ...      ...
# 19999              ZP.MS        ['KIMA']  MKWDDN_8856               en
# 20000              ZP.MS        ['KIMA']  MKWDDN_8856               en
# 20001              ZP.MS        ['KIMA']  MKWDDN_8856               en
# 20002              ZP.MS        ['KIMA']  MKWDDN_8856               en
# 20003              ZP.MS        ['KIMA']  MKWDDN_8856               en
#
# [20004 rows x 25 columns]

# %% [markdown]
# Als we kijken naar de essentiële DarwinCore elementen, zien we dat deze (bijna) allemaal gevuld kunnen worden door de Aquadesk data als volgt:
# - eventDate:
# Gegeven door de “ResultTime” kolom, e.g. 2022-12-31T23:00:00Z.
# - eventID:
# Niet expliciet aanwezig, zou kunnen worden gegenereerd door bijvoorbeeld kolommen samen te nemen zoals de “Organisation”, “Projects” en “Code”.
# - decimalLongitude & decimalLatitude:
# Beschikbaar binnen “GeoGraphy”, die Polygonen en MultiPolygonen bevat. Wij hebben het middelpunt genomen van deze Polygonen voor elke meting als Longitude en Latitude waarde.
# - occurrenceID:
# Niet expliciet aanwezig, zou kunnen worden gegenereerd door bijvoorbeeld kolommen samen te nemen zoals de “Organisation”, “Longitude”, “Latitude”, “ResultTime” en “Parameter”.
# - scientificName:
# Gegeven door de “Parameter” kolom, e.g. Phalacrocorax carbo.
# - occurrenceStatus:
# De noodzakelijke identificatie in de vorm van presence of absence kan worden afgeleid van het aantal gemeten beestjes via de “count” kolom.
# - basisOfRecord:
# Gegeven door de “ResultOf” kolom, e.g. observations, extrapolation, observed.
